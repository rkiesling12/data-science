# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
# %matplotlib inline

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Thinkful-Ed/data-201-resources/master/cleveland.csv", header=None, error_bad_lines=False)

# Define the features and the outcome.
X = df.iloc[:, :13]
y = df.iloc[:, 13]

# Replace missing values (marked by ?) with a 0.
X = X.replace(to_replace='?', value=0)

# Binarize y so that 1 means heart disease diagnosis and 0 means no diagnosis.
y = np.where(y > 0, 0, 1)

# %%
# Normalize the data.
X_norm = normalize(X)

# Reduce it to two components.
X_pca = PCA(2).fit_transform(X_norm)

# Calculate predicted values.
y_pred = KMeans(n_clusters=2, random_state=42).fit_predict(X_pca)

# Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1
# row_0
# 0      84  65
# 1      55  99

# %%
# Each batch will be made up of 200 data points.
minibatchkmeans = MiniBatchKMeans(
    init='random',
    n_clusters=2,
    batch_size=200)
minibatchkmeans.fit(X_pca)

# Add the new predicted cluster memberships to the data frame.
predict_mini = minibatchkmeans.predict(X_pca)

# Check the MiniBatch model against our earlier one.
print('Comparing k-means and mini batch k-means solutions:')
print(pd.crosstab(predict_mini, y_pred))
# Out:
# Comparing k-means and mini batch k-means solutions:
# col_0    0    1
# row_0
# 0      139    0
# 1       10  154

# %%
# Normalize the data.
X_norm = normalize(X)

# Reduce it to two components.
X_pca = PCA(2).fit_transform(X_norm)

# Calculate predicted values.
y_pred = KMeans(n_clusters=3, random_state = 42).fit_predict(X_pca)

# Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1
# row_0
# 0      65  70
# 1      25  61
# 2      49  33

# %%
print(pd.crosstab(y_pred, y).iloc[2, 0], pd.crosstab(y_pred, y).iloc[2, 1])
print(pd.crosstab(y_pred, y).iloc[0, 0] + pd.crosstab(y_pred, y).iloc[1, 0], pd.crosstab(y_pred, y).iloc[0, 1] + pd.crosstab(y_pred, y).iloc[1, 1])
# Out:
# 49 33
# 90 131

# %%
# Normalize the data.
X_norm = normalize(X)

# Reduce it to two components.
X_pca = PCA(2).fit_transform(X_norm)

# Calculate predicted values.
y_pred = KMeans(n_clusters=4, random_state=42).fit_predict(X_pca)

# Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1
# row_0
# 0      40  21
# 1      37  67
# 2      42  20
# 3      20  56

# %%
print(pd.crosstab(y_pred, y).iloc[0, 0] + pd.crosstab(y_pred, y).iloc[2, 0], pd.crosstab(y_pred, y).iloc[0, 1] + pd.crosstab(y_pred, y).iloc[2, 1])
print(pd.crosstab(y_pred, y).iloc[1, 0] + pd.crosstab(y_pred, y).iloc[3, 0], pd.crosstab(y_pred, y).iloc[1, 1] + pd.crosstab(y_pred, y).iloc[3, 1])
# Out:
# 82 41
# 57 123

# %%
# Normalize the data.
X_norm = normalize(X)

# Reduce it to two components.
X_pca = PCA(2).fit_transform(X_norm)

# Calculate predicted values.
y_pred = KMeans(n_clusters=5, random_state=42).fit_predict(X_pca)

# Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1
# row_0
# 0      15  21
# 1      36  12
# 2      14  58
# 3      34  45
# 4      40  28

# %%
print(pd.crosstab(y_pred, y).iloc[1, 0] + pd.crosstab(y_pred, y).iloc[4, 0], pd.crosstab(y_pred, y).iloc[1, 1] + pd.crosstab(y_pred, y).iloc[4, 1])
print(pd.crosstab(y_pred, y).iloc[0, 0] + pd.crosstab(y_pred, y).iloc[2, 0] + pd.crosstab(y_pred, y).iloc[3, 0], pd.crosstab(y_pred, y).iloc[0, 1] + pd.crosstab(y_pred, y).iloc[2, 1]+ pd.crosstab(y_pred, y).iloc[3, 1])
# Out:
# 76 40
# 63 124

# %%
# Normalize the data.
X_norm = normalize(X)

# Reduce it to two components.
X_pca = PCA(2).fit_transform(X_norm)

# Calculate predicted values.
y_pred = KMeans(n_clusters=6, random_state=42).fit_predict(X_pca)

# Plot the solution.
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred)
plt.show()

# Check the solution against the data.
print('Comparing k-means clusters against the data:')
print(pd.crosstab(y_pred, y))
# Out:
# Comparing k-means clusters against the data:
# col_0   0   1
# row_0
# 0      14  52
# 1      20  21
# 2      34  20
# 3      14  21
# 4      23   6
# 5      34  44

# %%
print(pd.crosstab(y_pred, y).iloc[2, 0] + pd.crosstab(y_pred, y).iloc[4, 0], pd.crosstab(y_pred, y).iloc[2, 1] + pd.crosstab(y_pred, y).iloc[4, 1])
print(pd.crosstab(y_pred, y).iloc[0, 0] + pd.crosstab(y_pred, y).iloc[1, 0] + pd.crosstab(y_pred, y).iloc[3, 0] + pd.crosstab(y_pred, y).iloc[5, 0], pd.crosstab(y_pred, y).iloc[0, 1] + pd.crosstab(y_pred, y).iloc[1, 1]+ pd.crosstab(y_pred, y).iloc[3, 1]+ pd.crosstab(y_pred, y).iloc[5, 1])
# Out:
# 57 26
# 82 138

# %% [markdown]
# For this assignment, I tried using a k of 3, 4, 5, and 6 to see how those groups would map to the binary outcome. Then I categorized each group based on the most common outcome and combined the groups for each outcome. In this case, the model with 4 K-means performed the best.
